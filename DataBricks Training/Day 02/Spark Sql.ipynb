# %%
# %sql
CREATE TABLE acc_dev.rithesh.financial_parquet as
select * from parquet.`/Volumes/acc_dev/naval/raw/house-price.parquet`

# %%
# %sql
SELECT * FROM acc_dev.rithesh.financial_parquet

# %%
# %sql
CREATE TABLE acc_dev.rithesh.retail_json 
select * from json.`/Volumes/acc_dev/naval/raw/retail_orders.json`

# %%
# %sql
 select * from acc_dev.rithesh.retail_json

# %%
# %sql
select * from json.`/Volumes/acc_dev/naval/raw/1.json`

# %%
# %sql
select * from read_files("/Volumes/acc_dev/naval/raw/1.json",format=>'json')
