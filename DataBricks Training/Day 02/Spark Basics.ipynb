# %% [markdown]
# Writer API

# %%
spark

# %%
data = [(1,'a'),(2,'b'),(3,'c')]
df = spark.createDataFrame(data, ['id','name'])
df.show()

# %%
df.display()

# %%
from datetime import datetime,date
from pyspark.sql import Row
df = spark.createDataFrame([
        Row(a=1,b=1,c=date(2000,1,1),d=datetime(2000, 1, 1, 12, 0)),
            Row(a=1,b=1,c=date(2000,1,1),d=datetime(2000, 1, 1, 12, 0)),
            Row(a=1,b=1,c=date(2000,1,1),d=datetime(2000, 1, 1, 12, 0))]
)

# %%
df.show()

# %%
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df.show()

# %% [markdown]
# Reader API

# %%
df_sales = spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv",header=True,inferSchema=True)
df_sales.write.mode("overwrite").saveAsTable("acc_dev.rithesh.sales_py")

# %%
df_sales.display

# %%
# %sql
select * from acc_dev.rithesh.sales_py

# %%
df_parquet = spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet")
df_parquet.display()

# %%
df_parquet.write.mode("append").saveAsTable("acc_dev.rithesh.house_py")

# %%
# %sql
select * from acc_dev.rithesh.house_py

# %%
df_json = spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")

# %%
df_json.display()
