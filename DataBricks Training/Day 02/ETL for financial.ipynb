# %% [markdown]
# ###End to End Financial

# %%
# %run "/Workspace/Users/ritheshadep@gmail.com/DataBricks Training/Day 02/includes"

# %%
df = spark.read.csv(input_path,header=True,inferSchema = True)

# %%
df = df.withColumnsRenamed({'TransactionID':'transaction_Id','CustomerID':'customer_id','AccountType':'account_type','TransactionType':'transaction_type','AmountUSD':'amount_usd','Branch':'branch','TransactionDate':'transaction_date'})

# %%
# %skip
new_col=['transaction_id',
 'customer_id',
 'account_type',
 'transaction_type',
 'amount_usd',
 'branch',
 'transaction_date']

# %%
# %skip
df=df.toDF(*new_col)

# %%
df = df.withColumns({"Ingestion_Date": current_timestamp(),"Ingestion_path":lit("/Volumes/acc_dev/naval/raw/financial_dataset.csv")})

# %%
df.write.mode("overwrite").saveAsTable("acc_dev.rithesh.financial_py")

# %%
# %sql
select * from  acc_dev.rithesh.financial_py
