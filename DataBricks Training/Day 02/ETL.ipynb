# %% [markdown]
# Step 1: Extracting

# %%
from pyspark.sql.functions import *

# %%
df  =spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv",header=True,inferSchema=True)

# %%
df.select("CustomerID")

# %%
df.select(col("CustomerID").alias("Cust_ID")).display()

# %%
df.withColumnRenamed("AccountType", "Accctype").withColumnRenamed("TransactionID","T_Id").display()

# %%
df.withColumnsRenamed({"TransactionId": "T_id", "AccountType": "Accctype"}).display()

# %%
df.withColumn("Ingestion_time",current_date())
