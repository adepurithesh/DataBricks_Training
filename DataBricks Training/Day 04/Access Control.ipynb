# %%
# %sql
grant usage on schema acc_dev.rithesh_bronze to `nithinsaireddy7@gmail.com`;

# %%
# %sql
grant select on schema acc_dev.rithesh_bronze to `nithinsaireddy7@gmail.com`;

# %%
# %sql
REVOKE SELECT ON SCHEMA acc_dev.rithesh_bronze FROM `nithinsaireddy7@gmail.com`;

# %%
# %sql
select * from acc_dev.naval_gold.agg_heartrate
