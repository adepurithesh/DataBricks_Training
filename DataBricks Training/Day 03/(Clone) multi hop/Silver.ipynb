# %%
# %run "/Workspace/Users/ritheshadep@gmail.com/DataBricks Training/Day 03/(Clone) multi hop/includes"

# %%
df = spark.table(f"{catalog}.{schema}.sales")

# %%
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

# %%
df1.write.mode("overwrite").saveAsTable(f"{catalog}.rithesh_silver.sales_cleaned")
