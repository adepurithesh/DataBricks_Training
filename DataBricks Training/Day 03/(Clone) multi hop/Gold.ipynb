# %%
# %sql
CREATE VIEW ACC_DEV.RITHESH_GOLD.SALES AS (
select customer_id,sum(total_amount) as Total_Amount from acc_dev.rithesh_silver.sales_cleaned
group BY customer_id)
# Out:
# Databricks data profile. Run in Databricks to view.
