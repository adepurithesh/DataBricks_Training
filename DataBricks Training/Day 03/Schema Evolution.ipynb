# %%
data=([(1,'Virat'),(2,'Rohit')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("overwrite").saveAsTable("acc_dev.rithesh.Cricket")

# %%
# %sql
select * from acc_dev.rithesh.cricket

# %%
data=([(3,'Jadeja'),(4,'Ashwin')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").saveAsTable("acc_dev.rithesh.Cricket")

# %%
data=([(4,'Sachin','Batsman'),(5,'Dhoni','WK')])
schema="id int, name string, Role string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").option("mergeSchema",True).saveAsTable("acc_dev.rithesh.Cricket")
