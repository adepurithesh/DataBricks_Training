-- %%
%sql
use catalog acc_dev;
use schema rithesh;

-- %%
%sql
CREATE TABLE emp(Id int, Name string, City STRING);

-- %%
%sql
select * from emp

-- %%
%sql
insert into emp values(1,'Rithesh','Hyd')

-- %%
%sql
desc extended emp;

-- %%
%sql
desc history emp

-- %%
%sql
desc detail emp

-- %%
%sql
insert into emp values(2,'Nithin','Hyderabad')

-- %%
%sql
insert into emp values (3,'Raju','Mumbai')

-- %%
%sql
select * from emp

-- %%
%sql
delete from emp where id=3;

-- %% [markdown]
-- Time Travel

-- %%
%sql
select * from emp version as of 3

-- %%
%sql
select * from emp timestamp as of '2025-11-05T05:03:56.000+00:00'

-- %%
%sql
insert into acc_dev.naval.emp values (28,'Rithesh','Hyd')

-- %%
%sql
select * from acc_dev.naval.emp

-- %% [markdown]
-- ##Restore

-- %%
restore table emp version as of 3
