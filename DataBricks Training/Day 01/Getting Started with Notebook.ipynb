# %% [markdown]
# ## Databricks Notebook

# %%
print("Hello!!")

# %%
# %sql
select "Run SQL"

# %% [markdown]
# Data Objects
# - CataLog
# - Schema
# - Tables, Views, volumes, functions

# %%
# %sql
use catalog acc_dev;
CREATE SCHEMA IF Not Exists Rithesh;

# %%
# %sql
use schema rithesh;
create table acc_dev.rithesh.demo (id int primary key)

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)
